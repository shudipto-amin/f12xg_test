# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import matplotlib as mpl
import os 
# %matplotlib widget

# %% [markdown]
# # Compare energies

# %%
data

# %%
csvs = get_files('./default/3C_FIX/aug-cc-pwCVDZ/')
print(csvs)
labels = [os.path.basename(f).rstrip('.csv').split('default_core')[-1] for f in csvs]
labels

# %%
df = get_df(csvs, labels)

# %%
cols = [col for col in df.columns if 'core-1' not in col and 'TOT_ENER' not in col]
filt_df = df[cols]
print(filt_df.to_string(index=False))

# %%
df.plot(x='GEM_BETA', y=['CORR_ENER_core', 'CORR_ENER'], xlabel=r'$\gamma$', ylabel='Energy')
