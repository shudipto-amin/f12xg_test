# %%
import matplotlib.pyplot as pp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
import analyse_methods as am
from importlib import reload
import os
import sys


sys.path.append(os.path.abspath('../'))
# %matplotlib widget
print(sys.path)

from __visuals__ import matplot

# %%
reload(matplot)

# %% [markdown]
# ## Styling

# %%
style_sheet = "../__visuals__/f12xg_plot_style.mplstyle"
pp.style.use(style_sheet)

# %%
elements = [
    "h", "he", "li", "be", "b", "c", "n", "o", "f", "ne",
    "na", "mg", "al", "si", "p", "s", "cl", "ar", "k", "ca",
    "sc", "ti", "v", "cr", "mn", "fe", "co", "ni", "cu", "zn",
    "ga", "ge", "as", "se", "br", "kr", "rb", "sr", "y", "zr",
    "nb", "mo", "tc", "ru", "rh", "pd", "ag", "cd", "in", "sn",
    "sb", "te", "i", "xe", "cs", "ba", "la", "ce", "pr", "nd",
    "pm", "sm", "eu", "gd", "tb", "dy", "ho", "er", "tm", "yb",
    "lu", "hf", "ta", "w", "re", "os", "ir", "pt", "au", "hg",
    "tl", "pb", "bi", "po", "at", "rn", "fr", "ra", "ac", "th",
    "pa", "u", "np", "pu", "am", "cm", "bk", "cf", "es", "fm",
    "md", "no", "lr", "rf", "db", "sg", "bh", "hs", "mt", "ds",
    "rg", "cn", "nh", "fl", "mc", "lv", "ts", "og"
]

# %% [markdown]
# ## Non-interactive

# %%
# ~~ CHATGPT SUGGESTS
reload(am)
def plot_single(
    ax, basis=None, atom=None, charge=None, 
    fname=None, names=None, show_min=True, yscale=1, **plotkwargs,
    
):
    """Plot energy vs gamma for a one file."""
    if fname != None:
        data = pd.read_csv(fname, names=names, skipinitialspace=True)
    else:
        data = am.get_evsgamma(atom, basis, charge=charge)
    if data is None:
        return None
    line, = ax.plot(
        data.GEM_BETA, yscale * (data.E - min(data.E)),
        **plotkwargs,
    )
    if show_min:
        min_gamma = data.GEM_BETA[data.E.idxmin()]
        ax.axvline(min_gamma, color=line.get_color(), linestyle='--')
    return line, data


def plot_all_elements(basis, elements, blocks_dict, yscale=10**3, save=False):
    nblocks = len(blocks_dict)

    # Grid layout for subplots
    ncols = int(nblocks**0.5 + 0.5)
    nrows = (nblocks + ncols - 1) // ncols

    fig, axes = pp.subplots(nrows, ncols, figsize=(4*ncols, 4*nrows), squeeze=False)
    axes = axes.flatten()

    fig._axis_data = []  # store per-axis metadata in the figure

    axnum = 0
    cmap = pp.get_cmap("viridis")
    
    for ax, (block, data_list) in zip(axes, blocks_dict.items()):
        ax.set_title(f"{block}")
        n = len(data_list)

        norm = mcolors.Normalize(vmin=0, vmax=1.01*(n-1))

        line_map = {}  # for this axis
        active_element = {"name": None}

        for i, atom in enumerate(data_list):
            #print(atom)
            color = cmap(norm(i))
            
            if atom.startswith('FILE:'):
                fname, label = atom.split('>LABEL:')
                fname = fname.lstrip('FILE:')
                line, data = plot_single(
                    ax, fname=fname, yscale=yscale,
                    color=color, label=label
                )
            
            else:
                if '+' in atom:
                    atom, charge = atom.split('+')
                    charge = f'+{charge}'
                elif '-' in atom:
                    atom, charge = atom.split('-')
                    charge = f'-{charge}'
                else:
                    charge = 0
                label = f"{atom}{charge if charge else ''}".title()
                charge = int(charge)
                
                
                
                line, data = plot_single(
                    ax, basis=basis, atom=atom, charge=charge, 
                    color=color, label=label, yscale=yscale
                )
                
            #print(label)
            line_map[label] = line
            gamma_min = am.get_min(data)
            #ax.axvline(gamma_min, color=line.get_color(), linestyle="--")
        if axnum // ncols == nrows -1:
            ax.set_xlabel(r"$\gamma$")
        if axnum % ncols == 0:
            ax.set_ylabel("Energy (mH)")
        axnum+=1
        sm = cm.ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cbar = pp.colorbar(sm, ax=ax, ticks=range(n))
        #cbar.set_label("Element")
        cbar.set_ticklabels(line_map.keys())

        # Make tick labels pickable
        for label in cbar.ax.get_yticklabels():
            label.set_picker(True)

        ax.set_ylim(0 * yscale, 0.02 * yscale)
        ax.set_xlim(0.75 , 2.75)


    # remove unused subplots if any
    for ax in axes[nblocks:]:
        fig.delaxes(ax)


    if save:
        fname = f"energy_vs_gamma_{basis}.svg"
        fig.savefig(fname)

    fig.suptitle(rf"Basis: {basis}", fontsize=22)
    return fig

# %%
blocks_dict = {
    "Period-2, S-block" : ["li", "be"], 
    "Period-2, P-block" : ["b", "c", "n", "o", "f", "ne"],
    "Period-3, S-block" : ["na", "mg"],
    "Period-3, P-block" : ["al", "si", "p", "s", "cl", "ar"],    
    #"s-block": ["li", "be", "na", "mg", "k", "ca",],
    #"d-block": ["sc", "ti", "v", "cr", "mn", "fe", "co", "ni", "cu", "zn",
    #      ],
    #"p-block": ["he", "b", "c", "n", "o", "f", "ne",
    #      "al", "si", "p", "s", "cl", "ar",
    #      "ga", "ge", "as", "se", "br", "kr"]
}

# %% [markdown]
# ## The Gamma curves

# %% [markdown]
# ## Interactive part

# %%
# ~~ CHATGPT SUGGESTS
reload(am)
def plot_single(
    ax, basis=None, atom=None, charge=None, 
    fname=None, names=None, show_min=True, yscale=1, **plotkwargs,
    
):
    """Plot energy vs gamma for a one file."""
    if fname != None:
        data = pd.read_csv(fname, names=names, skipinitialspace=True)
    else:
        data = am.get_evsgamma(atom, basis, charge=charge)
    if data is None:
        return None
    line, = ax.plot(
        data.GEM_BETA, yscale * (data.E - min(data.E)),
        **plotkwargs,
    )
    if show_min:
        min_gamma = data.GEM_BETA[data.E.idxmin()]
        ax.axvline(min_gamma, color=line.get_color(), linestyle='--')
    return line, data


def plot_all_elements(basis, elements, blocks_dict, yscale=10**3, save=False):
    nblocks = len(blocks_dict)

    # Grid layout for subplots
    ncols = int(nblocks**0.5 + 0.5)
    nrows = (nblocks + ncols - 1) // ncols

    fig, axes = pp.subplots(nrows, ncols, figsize=(4*ncols, 4*nrows), squeeze=False)
    axes = axes.flatten()

    fig._axis_data = []  # store per-axis metadata in the figure

    axnum = 0
    cmap = pp.get_cmap("viridis")
    
    for ax, (block, data_list) in zip(axes, blocks_dict.items()):
        ax.set_title(f"{block}")
        n = len(data_list)

        norm = mcolors.Normalize(vmin=0, vmax=1.01*(n-1))

        line_map = {}  # for this axis
        active_element = {"name": None}

        for i, atom in enumerate(data_list):
            #print(atom)
            color = cmap(norm(i))
            
            if atom.startswith('FILE:'):
                fname, label = atom.split('>LABEL:')
                fname = fname.lstrip('FILE:')
                line, data = plot_single(
                    ax, fname=fname, yscale=yscale,
                    color=color, label=label
                )
            
            else:
                if '+' in atom:
                    atom, charge = atom.split('+')
                    charge = f'+{charge}'
                elif '-' in atom:
                    atom, charge = atom.split('-')
                    charge = f'-{charge}'
                else:
                    charge = 0
                label = f"{atom}{charge if charge else ''}".title()
                charge = int(charge)
                
                
                
                line, data = plot_single(
                    ax, basis=basis, atom=atom, charge=charge, 
                    color=color, label=label, yscale=yscale
                )
                
            #print(label)
            line_map[label] = line
            gamma_min = am.get_min(data)
            #ax.axvline(gamma_min, color=line.get_color(), linestyle="--")
        if axnum // ncols == nrows -1:
            ax.set_xlabel(r"$\gamma$")
        if axnum % ncols == 0:
            ax.set_ylabel("Energy (mH)")
        axnum+=1
        sm = cm.ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cbar = pp.colorbar(sm, ax=ax, ticks=range(n))
        #cbar.set_label("Element")
        cbar.set_ticklabels(line_map.keys())

        # Make tick labels pickable
        for label in cbar.ax.get_yticklabels():
            label.set_picker(True)

        ax.set_ylim(0 * yscale, 0.02 * yscale)
        ax.set_xlim(0.75 , 2.75)

        # store metadata: axis, lines, active element, and cbar ticklabels
        fig._axis_data.append({
            "ax": ax,
            "line_map": line_map,
            "active_element": active_element,
            "ticklabels": cbar.ax.get_yticklabels(),
        })

    # remove unused subplots if any
    for ax in axes[nblocks:]:
        fig.delaxes(ax)

    # --- Interactive toggle logic ---
    def on_pick(event):
        if isinstance(event.artist, pp.Text):
            picked_label = event.artist.get_text()
    
            for axis_info in fig._axis_data:
                if event.artist in axis_info["ticklabels"]:
                    line_map = axis_info["line_map"]
                    active_element = axis_info["active_element"]
    
                    if picked_label not in line_map:
                        continue
    
                    if active_element["name"] == picked_label:
                        # Reset all lines
                        for line in line_map.values():
                            line.set_alpha(1.0)
                        # Reset label style
                        event.artist.set_fontweight("normal")
                        active_element["name"] = None
                    else:
                        # Highlight picked, dim others
                        for atom, line in line_map.items():
                            line.set_alpha(1.0 if atom == picked_label else 0.25)
                        # Reset all label styles in this axis
                        for lbl in axis_info["ticklabels"]:
                            lbl.set_fontweight("normal")
                        # Set active label bold
                        event.artist.set_fontweight("bold")
                        active_element["name"] = picked_label
    
                    fig.canvas.draw_idle()
                    break  # stop after finding the right axis

    fig.canvas.mpl_connect("pick_event", on_pick)

    if save:
        fname = f"energy_vs_gamma_{basis}.svg"
        fig.savefig(fname)

    fig.suptitle(rf"Basis: {basis}", fontsize=22)
    return fig

# %%
basis = "aug-cc-pvtz"
fig = plot_all_elements(
    basis, elements, blocks_dict)
fig.tight_layout()

# %%
tt = fig.axes[0].yaxis.get_label()
print(tt.get_text().replace('(H', '(mH'))

# %%
ax = fig.axes[0]#.yaxis.get_label()
reload(matplot)
matplot.convert_units(ax)

# %%
fig.savefig("Energy_vs_gamma_elements.svg", transparent=True)

# %% [markdown]
# ## P4 elements

# %%
blocks_dict = {
    "Period-4, S-block" : ["k", "ca"],
    "Period-4, D-Block" : [
        "sc", "ti", "v", "cr", "mn", "fe", 
        "co", "ni", "cu", "zn"],
    "Period-4, P-Block" :  "ga ge as se br kr".split(),
    "Nobel elements" : ["he", "ne", "ar", "kr"]
}

# %%
basis = "aug-cc-pvtz"
fig = plot_all_elements(
    basis, elements, blocks_dict)
fig.tight_layout()

# %% [markdown]
# ## Two or three elements

# %%
blocks_dict = {
    "" : ["cu", "n"],
}

# %%
basis = "aug-cc-pvtz"
fig, ax = pp.subplots()
plot_single(
    ax, basis=basis, atom='n', charge=0, 
    fname=None, names=None, show_min=False, yscale=10**3, label='N', 
)
plot_single(
    ax, basis=basis, atom='cu', charge=0, 
    fname=None, names=None, show_min=False, yscale=10**3, label='Cu',
)

ax.set_ylim(0,20)
ax.set_xlim(0.5, 2.9)
ax.set_ylabel('Energy (mH)')
ax.set_xlabel(r'$\gamma$')
ax.legend()
fig.tight_layout()

# %%
fig.savefig("Energy_vs_gamma_cu_n.svg")

# %%
bases = ["aug-cc-pvtz", "awcvtz"]
#basis= bases[0]
basis = bases[0]
fig = plot_all_elements(
    basis, elements, {
        "Cu+, Cu, N, and NH3":
        ["cu+1", "cu", "n", 'FILE:../dimers/cu_nh3/optimize_nh3_gamma/table_nh3_0_aug-cc-pvtz.csv>LABEL:NH3'],
                      
                    #"d": ["sc", "ti", "v", "cr", "mn", "fe", "co", "ni", "cu", "zn",],
                     })#blocks_dict)

fig.suptitle(fr'Energy vs $\gamma$ for {basis}')
fig.tight_layout()

# %%
fig.savefig('comparing_cu_cu1_n_nh3.svg')

# %%
plot_single(fig.gca(), fname='../dimers/cu_nh3/optimize_nh3_gamma/table_nh3_0_aug-cc-pvtz.csv')

# %%
"df".title()

# %%
blocks_dict['noble'] = ['he', 'ne', 'ar']
fig = plot_all_elements(
    basis, elements, blocks_dict)
fig.tight_layout()

# %%
fig.savefig("energy_vs_gamma_elements_by_block.svg")
