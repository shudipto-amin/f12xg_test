# %%
import numpy as np

import os
import matplotlib.pyplot as pp
from importlib import reload
from matplotlib.colors import TABLEAU_COLORS 

import sys
sys.path.append('../')
import _daily_reporters as dr
import pickle

# %matplotlib widget

# %%
def load_pkl(fname):
    with open(fname, 'rb') as f:
        obj = pickle.load(f)
    return obj

# %%
fig = load_pkl('Ar_Ne_BSE.pkl')

# %% [markdown]
# ## Inlet

# %%
fig.set_size_inches(7,3)

# %%
fig.savefig('Ar_Ne_BSE_inlet.svg')

# %% [markdown]
# ## Fig with new ylim

# %%
ax = fig.axes[0]
ax.set_ylim(None, -300)
fig

# %%
fig.savefig('Ar_Ne_BSE.svg')

# %% [markdown]
# # Modifying the limits of difference in energy

# %%
fig = load_pkl('Ar_Ne_Diff_BSE.pkl')

# %%
ax, _ = fig.axes

# %%
ax.set_ylim(0.3, None)

# %%
fig.savefig('Ar_Ne_Diff_BSE.svg')
